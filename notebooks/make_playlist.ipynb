# %%
import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.neighbors import NearestNeighbors 
from scipy.spatial import KDTree
from sklearn.preprocessing import MinMaxScaler
import generate_playlist as gp
import numpy as np
pd.options.mode.chained_assignment = None  #

# %%
song_df = gp.load_song_db()
artists_df = gp.load_artist_db()

# %%
song_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists              id_artists  \
# 0       126903         0              ['Uli']  45tIt06XoI0Iio4LBEVpls
# 1        98200         0  ['Fernando Pessoa']  14jtPCOoNZwquk5wd9DxrY
# 2       181640         0  ['Ignacio Corsini']  5LiOoJbxVSAMkBS2fUm3X2
# 3       176907         0  ['Ignacio Corsini']  5LiOoJbxVSAMkBS2fUm3X2
# 4       163080         0      ['Dick Haymes']  3BiJGZsyX9sJchTqcSA7Su
#
#   release_date  danceability  energy  ...  loudness  mode  speechiness  \
# ...

# %%
artists_df.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0
# 1  0DlhY15l3wsrnlfGio2bjU        5.0
# 2  0DmRESX2JknGPQyO15yxg7        0.0
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %% [markdown]
# ### Find similar songs
#
# - use KNN
# - find similare songs among metalcore songs
#
# the song database requires still some filtering as similar song (same artist and name) can have multiple entries with only slight variations

# %%
# find metalcore artists
metalcore_artists = artists_df[artists_df["genres"].str.contains("metalcore")]["id"].tolist()
# subset df by metalcore artists
metalcore_songs = song_df[song_df["id_artists"].isin(metalcore_artists)]
theblack = "4ORXSxr4tV5H6gH5KHAiAh"
# make playlist of 25 songs
gp.knn_song_recommendation(song_id=theblack, df= metalcore_songs, n_songs = 25, subset_genre = False,related_artists = False)
# Out:
# 278
#                          id  \
# 278  4ORXSxr4tV5H6gH5KHAiAh
# 104  0m5PQFyWWwclSA0T813jnU
# 178  4ubsyGydOcYNC3B9mxuN8l
# 198  2UPgznAke4X6iSvFFbbyjd
# 224  7AUVdpcqbxLSCOQqKHjPx7
# 352  3eSnqrgqm1R0mkgz80Cpzq
# 207  2C5jGbR23YLonV7Lton6fV
# 175  4Z7mFMK6NvAxZSCwe07hwk
# 252  4MjJlPgUYMQjvHOQq0uvOv
# 259  344tr5lxfDxXdcvz67kvlO
# 326  5S9fYXUmUcsPR3GtLaT757
# 347  5JWDt4NZNiZQR8iMenaa7h
# 83   1z3LsJRCvln5qO5TOLduQM
# 377  1EJzHoU6rg1afMozs9t6aM
# 290  0A6PfIp2V8Z5L8rqKUpDvG
# 28   0UOt7Bf2xLKjR8BqJRRdQN
# 15   12U7FzFoTcxjuwrPapKsP6
# 289  3LyliKFPMvddPOyCv2hgt6
# 317  47yN6ORMNO3CRnUgGr2hAc
# 138  2qRd9uRath54PcJglk1xpf
# 294  188aOUbxUOJfRZte4su9ax
# 229  7lMFAK8dv0QkWpIlZcWQlJ
# 91   4R3jnxlZwFrIMq2YYoFJFi
# 291  6hZkQjIQBY7HAj4nzLUvdx
# 349  0CbESIyx34Usxoy7emUEBd
#
#                                                   name  popularity  \
# 278                                          The Black          60
# ...
