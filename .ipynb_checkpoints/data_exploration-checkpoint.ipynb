# %%
import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.neighbors import NearestNeighbors 
from scipy.spatial import KDTree
from sklearn.preprocessing import MinMaxScaler
import numpy as np
pd.options.mode.chained_assignment = None  #

# %%
artists = pd.read_csv('data/artists.csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
artists.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0
# 1  0DlhY15l3wsrnlfGio2bjU        5.0
# 2  0DmRESX2JknGPQyO15yxg7        0.0
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
id_genre = artists[artists["genres"]!="[]"][["id", "genres"]]

# %%
id_genre[id_genre['genres'].str.contains('lo-fi')]
# Out:
#                              id  \
# 4741     6yz8H2Aks1bHaKNiHCutaR
# 14159    0djvqMepj2XkHfvWTqkH1N
# 14220    2pLu3Ut2C3RviYZ3xUanBs
# 19086    0ikgHu560bYMZOOXFQnRLN
# 20089    3Sb3oI3Xw7FcgYS262zXPE
# ...                         ...
# 1102827  2LsbZ4vhm7aWOEqBLZQfbX
# 1103093  6FsyvM4nmEVkHPWR79ymC7
# 1103094  4RaBcLfacDovpzQ38LnzMv
# 1103095  6dJ1iY51ZgNt93gelvdF3k
# 1103883  4FdSsjcX7vzOnN5zNqQWAy
#
#                                                     genres
# 4741     ['belo horizonte indie', 'brazilian lo-fi rock...
# 14159                          ['chillhop', 'lo-fi beats']
# 14220                                      ['lo-fi beats']
# 19086                          ['chillhop', 'lo-fi beats']
# 20089                                      ['lo-fi beats']
# ...                                                    ...
# 1102827  ['alternative pop', 'dayton indie', 'gbvfi', '...
# 1103093                                    ['lo-fi beats']
# ...

# %%
artists.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %%
df = pd.read_csv('data/tracks.csv.zip', compression='zip', header=0, sep=',', quotechar='"')
df["song"] = df["name"] + "_" + df["artists"]
# filter songs that are shorter than 7 minutes
df = df[df["duration_ms"] < 420000]

broad_genre = ["pop", "hip hop", "rock", "punk", "blues", "metal", "folklore", "r&b", "house", 
              "indie"]

# %%
artists['genres'] = artists['genres'].str.strip('[]').str.strip("''")
artists[artists["genres"].str.contains("german hip hop")]
# Out:
#                              id  followers  \
# 1123     1vLew3o8JIJ9XTCRkOCCbb    15260.0
# 1129     5YL5sKtxi1J4bApusQ2uwI    38778.0
# 1131     04M031J6AL6BMAl8mRYxHy     9625.0
# 1164     4Jd9XCHzRXTB7ZPPVzJoUm    19014.0
# 1186     5hNRMsMMDlMIvEwu4UvjQO    74884.0
# ...                         ...        ...
# 1099907  0lIUNGTBl9Kmk4likubv5M     2348.0
# 1099908  2J6g5uPhygXNpLV7vDBG2e     1800.0
# 1099909  7zpD1yBrSwyzVAxlphThLU     1395.0
# 1100060  6LgSabC1lm5tn3ARhPDlXL     8944.0
# 1100118  3inUuWUDpXPIpxIxzuQ1av      296.0
#
#                                                     genres           name  \
# 1123              german hip hop', 'german underground rap           Sipo
# 1129                          german hip hop', 'german pop       Thomas D
# 1131                                   deep german hip hop           Jeaw
# 1164                                        german hip hop         Milano
# ...

# %%
artists[artists["genres"].str.contains("['german hip hop']")]#["name"].tolist()#.values[0]#.value#[1]#.tolist()#[["id", "genres"]]
# Out:
#                              id  followers                            genres  \
# 45       0VLMVnVbJyJ4oyZs2L3Yl2       71.0                ['carnaval cadiz']
# 46       0dt23bs4w8zx154C5xdVyl       63.0                ['carnaval cadiz']
# 47       0pGhoB99qpEJEsBQxgaskQ       64.0                ['carnaval cadiz']
# 48       3HDrX2OtSuXLW5dLR85uN3       53.0                ['carnaval cadiz']
# 136      22mLrN5fkppmuUPsHx6i2G       59.0        ['classical harp', 'harp']
# ...                         ...        ...                               ...
# 1104328  1q9C5XlekzXbRLIuLCDTre    90087.0  ['social media pop', 'teen pop']
# 1104331  4fh2BIKYPFvXFsQLhaeVJp      309.0                      ['la indie']
# 1104334  7akMsd2vb4xowNTehv3gsY      774.0                 ['indie rockism']
# 1104336  35m7AJrUCtHYHyIUhCzmgi      205.0                 ['indie rockism']
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0             ['deep acoustic pop']
#
# ...

# %%
df['artists'].str.strip('[]').str.strip("''")#.astype(int)
# Out:
# 0                                 Uli
# 1                     Fernando Pessoa
# 2                     Ignacio Corsini
# 3                     Ignacio Corsini
# 4                         Dick Haymes
#                      ...
# 586667                        阿YueYue
# 586668                     ROLE MODEL
# 586669                        FINNEAS
# 586670    Gentle Bones', 'Clara Benin
# 586671                      Afrosound
# Name: artists, Length: 586672, dtype: object

# %%
d.sort_values("mean",ascending =False).index[0:25]
# Out:
# Index(['244AvzGQ4Ksa5637JQu5Gy', '3GNDBGICWkYOz6sUkZEBhQ',
#        '456WNXWhDwYOSf5SpTuqxd', '6dux5viG3Ku3IefPx3gFNT',
#        '39H9bPCzk6wowylEGgDCNC', '6KpO4neDXxGdiEgsivZieY',
#        '0Dkibk70FDp6t7eOZNemNQ', '3GL12BAZFVQPcCOAgPaSsT',
#        '71iSmEeF0qRVyULABxP75P', '4ACGa15ogiMGLQPCv2ay5b',
#        '61o9ek0A26KARnXBPssDv3', '6cC9RY7MoUx5z3aHjDTNI6',
#        '3MCKcHrpJdQm4pakk6tYHF', '76R8ILULQyyodS91TkAvOf',
#        '5XSU59wtE5CRCAEyHmmGy4', '6u9RqxALwkjJ1ukB1y8vuP',
#        '5YnZJsPu9ExFN3oQYMtPTu', '3HNTLCpAGnizbyJmk7466r',
#        '0K5I39R4ehtSCBDLktWyNY', '3Ehxf88npHMLIBEIM7Klus',
#        '4tgYdBU8IEmZwU9mAs6du1', '7sXDYdXmR2PnafjkpfdCYv',
#        '0jv5OcbvTUHgO8FgHhya8b', '1BncfTJAWxrsxyT9culBrj',
#        '0qnzHn8plo9r10x69uFJYS'],
#       dtype='object')

# %%
from scipy.spatial import distance
#u = df["ids"].str.get_dummies(",")

j = distance.pdist(h_e[features_list], "jaccard")
k = h_e["id"].to_numpy()
d = pd.DataFrame(1 - distance.squareform(j), index=k, columns=k)
d['mean'] = d.mean(axis=1)
d
# Out:
#                         456WNXWhDwYOSf5SpTuqxd  244AvzGQ4Ksa5637JQu5Gy  \
# 456WNXWhDwYOSf5SpTuqxd                1.000000                0.166667
# 244AvzGQ4Ksa5637JQu5Gy                0.166667                1.000000
# 1myEOhXztRxUVfaAEQiKkU                0.250000                0.083333
# 71iSmEeF0qRVyULABxP75P                0.166667                0.181818
# 57yeWyaoeTt26p0dlEZukQ                0.083333                0.083333
# ...                                        ...                     ...
# 7rtQTjYUw5GOpN2F4St52Y                0.083333                0.083333
# 5YnZJsPu9ExFN3oQYMtPTu                0.166667                0.166667
# 757Lj6O0Dy6E2darFj5NF5                0.166667                0.166667
# 7sXDYdXmR2PnafjkpfdCYv                0.166667                0.166667
# 61o9ek0A26KARnXBPssDv3                0.250000                0.166667
#
#                         1myEOhXztRxUVfaAEQiKkU  71iSmEeF0qRVyULABxP75P  \
# ...

# %%
h_e.head()
# Out:
# Empty DataFrame
# Columns: [danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]
# Index: []

# %%
h_e = pd.concat([df_florence, df_einaudi])
#idh_e = h_e.set_index("id")[features_list]
f = h_e[features_list].transpose()
corr = f.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# ...

# %%
corr.max()
# Out:
# id
# 456WNXWhDwYOSf5SpTuqxd    1.0
# 244AvzGQ4Ksa5637JQu5Gy    1.0
# 1myEOhXztRxUVfaAEQiKkU    1.0
# 71iSmEeF0qRVyULABxP75P    1.0
# 57yeWyaoeTt26p0dlEZukQ    1.0
#                          ...
# 7rtQTjYUw5GOpN2F4St52Y    1.0
# 5YnZJsPu9ExFN3oQYMtPTu    1.0
# 757Lj6O0Dy6E2darFj5NF5    1.0
# 7sXDYdXmR2PnafjkpfdCYv    1.0
# 61o9ek0A26KARnXBPssDv3    1.0
# Length: 111, dtype: float64

# %%
df[df["id"].str.contains("456WNXWhDwYOSf5SpTuqxd")]
# Out:
#                            id               name  popularity  duration_ms  \
# 82206  456WNXWhDwYOSf5SpTuqxd  Dog Days Are Over          74       252819
#
#        explicit                     artists                  id_artists  \
# 82206         0  ['Florence + The Machine']  ['1moxjboGR7GNWYIMWsRjgG']
#
#       release_date  danceability  energy  ...  loudness  mode  speechiness  \
# 82206         2009         0.501   0.809  ...    -5.264     1       0.0938
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 82206        0.0338           0.00602     0.119    0.258  149.964
#
#        time_signature                                          song
# 82206               4  Dog Days Are Over_['Florence + The Machine']
#
# [1 rows x 21 columns]

# %%
df[df["id"].str.contains("5YqG5AAPuvWbr13ySUgH9C")]
# Out:
#                            id                name  popularity  duration_ms  \
# 96522  5YqG5AAPuvWbr13ySUgH9C  The Salley Gardens          17       166960
#
#        explicit                                            artists  \
# 96522         0  ['Benjamin Britten', 'The Elizabethan Singers'...
#
#                                               id_artists release_date  \
# 96522  ['7MJ1pB5d6Vjmzep2zQlorn', '14mtDotEOmAK0UEZb9...   1960-01-01
#
#        danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 96522         0.196  0.0679  ...    -22.24     1       0.0396          0.99
#
#        instrumentalness  liveness  valence   tempo  time_signature  \
# 96522             0.158     0.106   0.0986  68.164               4
#
#                                                     song
# 96522  The Salley Gardens_['Benjamin Britten', 'The E...
#
# [1 rows x 21 columns]

# %%
def knn_songrecommendation(df, song_id, n_songs):
    features_list =  ['danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'time_signature']
    # extract features from song
    song_features = df[df['id'].str.contains(vsong_id)][features_list].iloc[0].tolist()
    model_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=20, n_jobs=-1)

# %%
import pandas as pd
from scipy.spatial import KDTree

dataA = pd.DataFrame(pd.np.random.rand(100, 100))
dataB = pd.DataFrame(pd.np.random.rand(100, 100))

kdB = KDTree(dataB.values)
x = kdB.query(dataA.values, k=70)# k desired number of neighbors 
#returns indices of 3-neighbors for all rows/points in A
from sklearn.neighbors import NearestNeighbors
X = df[features_list].to_numpy()
nbrs = NearestNeighbors(n_neighbors=3)
nbrs.fit(X)

def findsuccess(df, id):
    X = df[features_list].to_numpy()
    nbrs = NearestNeighbors(n_neighbors=20)
    nbrs.fit(X)
    neighbors_f_id = nbrs.kneighbors_graph([X[id]]).indices
    print  ('Neighbors of id', neighbors_f_id)
    return neighbors_f_id.tolist()
recom = findsuccess(df, 500113)
# Out:
# /var/folders/zc/tvqjw4cj7dvg_cps70bhwgwr0000gn/T/ipykernel_83780/1511303930.py:4: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# /var/folders/zc/tvqjw4cj7dvg_cps70bhwgwr0000gn/T/ipykernel_83780/1511303930.py:5: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# Neighbors of id [500113 526975 397782 312644 342363  90212 284373 575647 210603 285773
#  186550 108163 218352 501261 185591 157656 536461 437157 378919 561976]

# %%
df_halsey = df[df['artists'].str.contains('Halsey') & df['song'].str.contains('')]
favsong_df = df[df["id"].isin(favourite_songs)]
df_florence = df[df['artists'].str.contains('Florence \+ The Machine') & df['song'].str.contains('')]
df_riseagainst = df[df['artists'].str.contains('Rise Against') & df['song'].str.contains('')]
df_shawn = df[df['artists'].str.contains('Shawn Mendes') & df['song'].str.contains('')]
df_bmth = df[df['artists'].str.contains('Bring Me The Horizon') & df['song'].str.contains('')]
df_einaudi = df[df['artists'].str.contains('Ludovico Einaudi') & df['song'].str.contains('')]
df_apache = df[df['artists'].str.contains('Apache 207') & df['song'].str.contains('')]
df_hd = df[df['artists'].str.contains('Hollywood Undead') & df['song'].str.contains('')]
df_grimes = df[df['artists'].str.contains('Grimes') & df['song'].str.contains('')]
df_hd["group"] = 'Hollywood Undead'
df_apache["group"] = 'Apache 207'
df_bmth["group"] = 'Bring Me The Horizon'
df_riseagainst["group"] = 'Rise Against'
df_halsey["group"] = 'Halsey'
df_florence["group"] = 'Florence + The Machine'
favsong_df["group"] = "fav"
df_shawn["group"] = 'Shawn Mendes'
df_einaudi["group"] = 'Ludovico Einaudi'
df_grimes["group"] = "Grimes"

# %%
df2 = pd.concat([df_halsey, favsong_df, df_florence, df_riseagainst, df_shawn, df_einaudi, df_bmth, df_apache, df_hd, df_grimes])
pipeline = Pipeline([('scaling', StandardScaler()), ('pca', PCA(n_components=2))])

components = pipeline.fit_transform(df2[features_list])
fig = px.scatter(components, x=0, y=1, color=df2["group"], hover_name = df2["song"])
fig.show()

# %%
favourite_songs = ["2kP1ujXHn0mNqFbiT3zob8", "2eZjO58Qe9og2xmyfw4qwJ", "7CAbF0By0Fpnbiu6Xn5ZF7", "4TCL0qqKyqsMZml0G3M9IM",
                  "4ORXSxr4tV5H6gH5KHAiAh", "3dEFa9KjOLEZl980ctEEv1", "0cCi1Gf9lHNf6s17GwreLa",
                  "0hAIs32U2SmJcXymlcyF8h", "6lJbA3HMQlOI2JMdKbBKDi", "4mGdjNMo0RonTlOEb7cYg4",
                  "3SKzTIl9mW0DadTys9SFo3", "5p7ujcrUXASCNwRaWNHR1C"]

# %%
df_florence = df[df['artists'].str.contains('Joji')]

# %%
df_florence.head()
# Out:
#                            id                         name  popularity  \
# 90677  435yU2MvEGfDdmbH0noWZ0  worldstar money (interlude)          71
# 90918  0rKtyWc8bvkriBthvHKY8d     SLOW DANCING IN THE DARK          85
# 90989  1VGzxJnVQND7Cg5H5wGj14                   YEAH RIGHT          81
# 91161  0baNzeUcPQnQSagpe8T0mD  worldstar money (interlude)          77
# 91517  7wvwXi9Z66dcH5t202vVkN                      Will He          73
#
#        duration_ms  explicit   artists              id_artists release_date  \
# 90677       126312         1  ['Joji']  3MZsBdqDrRTJihTHQrO6Dq   2017-11-03
# 90918       209274         1  ['Joji']  3MZsBdqDrRTJihTHQrO6Dq   2018-10-26
# 90989       174358         1  ['Joji']  3MZsBdqDrRTJihTHQrO6Dq   2018-10-26
# 91161       126312         1  ['Joji']  3MZsBdqDrRTJihTHQrO6Dq   2018-02-14
# 91517       202103         1  ['Joji']  3MZsBdqDrRTJihTHQrO6Dq   2018-02-14
#
#        danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# ...

# %%
favsong_id = "2kP1ujXHn0mNqFbiT3zob8"
df[features_list].values
# Out:
# array([[6.45000e-01, 4.45000e-01, 0.00000e+00, ..., 1.27000e-01,
#         1.04851e+02, 3.00000e+00],
#        [6.95000e-01, 2.63000e-01, 0.00000e+00, ..., 6.55000e-01,
#         1.02009e+02, 1.00000e+00],
#        [4.34000e-01, 1.77000e-01, 1.00000e+00, ..., 4.57000e-01,
#         1.30418e+02, 5.00000e+00],
#        ...,
#        [5.35000e-01, 3.14000e-01, 7.00000e+00, ..., 6.63000e-02,
#         1.45095e+02, 4.00000e+00],
#        [6.96000e-01, 6.15000e-01, 1.00000e+01, ..., 4.38000e-01,
#         9.00290e+01, 4.00000e+00],
#        [6.86000e-01, 7.23000e-01, 6.00000e+00, ..., 9.75000e-01,
#         1.12204e+02, 4.00000e+00]])

# %%
def songrecommendation(favsong_id, n_songrecommendations,df):
    """
    """
    features_list =  ['danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'time_signature']
    
    song_features = df[df['id'].str.contains(favsong_id)][features_list].iloc[0].tolist()
    # remove favourite song from df
    df.drop(df[df['id'].str.contains(favsong_id)].index)
    df = df.set_index("id")
    #song_data = df.set_index("id")
    song_data = df[features_list]
    print(song_data.head())
    print(song_data.describe())
    
    
    dataA = pd.DataFrame(pd.np.random.rand(100, 100))
    dataB = pd.DataFrame(pd.np.random.rand(100, 100))

    kdB = KDTree(fav_song_df.values)
    print(kdB.query(dataA.values, k=3)[-1]) # k desired number of neighbors 
#returns indices of 3-neighbors for all rows/points in A
    song_indices, x = knn(
       song_data, song_features, k=n_songrecommendations,
        distance_fn=euclidean_distance, choice_fn=lambda x: None
    )
    song_suggestion_list = []
    for x, index in song_indices:
        song_suggestion_list.append(df[index])
    return song_suggestion_list


def songrecommendation2(songid_list, n_songrecommendations,df):
    
    favsong_df = df[df["id"].isin(songid_list)]
    favsong_df.set_index("id")
    scaler = MinMaxScaler()
    favsong_df = scaler.fit_transform(favsong_df[features_list])
    
    df.set_index("id")
    scaler = MinMaxScaler()
    song_db = scaler.fit_transform(df[features_list])
    kdB = KDTree(favsong_df)
    return kdB.query(song_db, k=10) # k desired number of neighbors 
#returns indices of 3-neighbors for all rows/points in A

def songrecom3():
    kmeans = KMeans(3)
    means.fit(x)
    favsong_df = df[df["id"].isin(songid_list)]
    favsong_df.set_index("id")
    scaler = MinMaxScaler()
    favsong_df = scaler.fit_transform(favsong_df[features_list])
    closest, _ = pairwise_distances_argmin_min(KMeans.cluster_centers_, X)
    kmeans = KMeans(3)
    kmeans.fit(x)
    identified_clusters = kmeans.fit_predict(x)
    identified_clusters
    data_with_clusters = data.copy()
    data_with_clusters['Clusters'] = identified_clusters 
    plt.scatter(data_with_clusters['Longitude'],data_with_clusters['Latitude'],c=data_with_clusters['Clusters'],cmap='rainbow')

# %%
x, v =songrecommendation2(favourite_songs, n_songrecommendations=10, df=df)

# %%
v
# Out:
# array([[ 4,  0,  2, ..., 11, 10,  6],
#        [ 2,  9,  1, ...,  3, 11,  5],
#        [ 2,  1,  8, ...,  4, 11,  5],
#        ...,
#        [ 1,  6, 11, ...,  7, 10,  9],
#        [ 8,  5,  2, ...,  7,  1, 10],
#        [ 8,  0,  5, ..., 10,  9,  6]])

# %%
scaler = MinMaxScaler()
scaler.fit_transform(df[features_list])
# Out:
# array([[0.65085772, 0.445     , 0.        , ..., 0.127     , 0.42556447,
#         0.6       ],
#        [0.70131181, 0.263     , 0.        , ..., 0.655     , 0.41402949,
#         0.2       ],
#        [0.43794147, 0.177     , 0.09090909, ..., 0.457     , 0.52933465,
#         1.        ],
#        ...,
#        [0.53985873, 0.314     , 0.63636364, ..., 0.0663    , 0.58890499,
#         0.8       ],
#        [0.70232089, 0.615     , 0.90909091, ..., 0.438     , 0.36540561,
#         0.8       ],
#        [0.69223007, 0.723     , 0.54545455, ..., 0.975     , 0.45540849,
#         0.8       ]])

# %%
song_id = "435yU2MvEGfDdmbH0noWZ0"
row = df[df["id"]==song_id].index[0]

# %%
row
# Out:
# 90677

# %%
X = df[features_list].to_numpy()
nbrs = NearestNeighbors(n_neighbors=n_songs)
nbrs.fit(X)
neighbors_f_id = nbrs.kneighbors_graph([X[id]]).indices
    # row numbers with recommended songs
recom = neighbors_f_id.tolist()

# %%
playlist_of_the_day()
# Out:
# Today is Monday, generating Lo-Fi playlist
#                             id               name  popularity  duration_ms  \
# 54069   4Av6uLF5s1A1mvSCP8fLR6                D-7          44       245067
# 54150   39NiB3VrlRX1RAvAMwv37y            Mystery          42       107907
# 54240   3obapaJgTQOm7ATIDBSm0c  Return of the Rat          41       157827
# 55000   59RkLuqY3LSqK3rJGds6cP     When It's Over          44       394120
# 55261   4wdKxYOszzCWgKOZT2pZgR   A Personal Issue          39       187867
# ...                        ...                ...         ...          ...
# 552953  01nLKbpSV14KyZwujAPRgV     Autumn Sweater          20       318373
# 553070  1bJ95d8h7KpCNpqRQ26mt6        Green Arrow          17       343800
# 571822  5rj4SmUDAe43tGtBgNgZnu              Romeo          26       245973
# 572367  2VFinC3whb3SJKwnMqTKFF         C.R.E.E.P.          22       176933
# 581858  5Yy3MkY3YEga1ecYOb2XqX   Papa Was a Rodeo          42       301547
#
# ...

# %%
df2 = df[df['artists'].str.contains('Halsey')]
joji = df[df['artists'].str.contains('Joji')]
get_similar_songs(genre_df= df2, songs_favourite_df = joji, n_songs= 25)
# Out:
#                             id                                          name  \
# 88316   1TnUURhehaoMWKAqQtirm6                                        Colors
# 90110   5k38wzpLb15YgncyWdTZE4                         Him & I (with Halsey)
# 90234   5ln5yQdUywVbf8HhFsOcd6                              Walls Could Talk
# 90948   5p7ujcrUXASCNwRaWNHR1C                                    Without Me
# 92997   3Z8FwOEN59mRMxDCtb8N0A                         Be Kind (with Halsey)
# 93249   1VSuFS7PahCN3SWbOcQ98m                  forget me too (feat. Halsey)
# 93420   5wWAwzGp2OaaoIkwcz6wZs                  Life's A Mess (feat. Halsey)
# 93546   6FZDfxM3a3UCqtzo5pxSLZ                                    Without Me
# 96522   5YqG5AAPuvWbr13ySUgH9C                            The Salley Gardens
# 231546  5iQ0Va8Dt5Yky4TXuqO5TF    Eastside (with Halsey & Khalid) - Acoustic
# 358169  4mGdjNMo0RonTlOEb7cYg4  11 Minutes (with Halsey feat. Travis Barker)
# ...

# %%
knn_song_recommendation("435yU2MvEGfDdmbH0noWZ0", n_songs = 25, subset_genre = False)
# Out:
#                             id                           name  popularity  \
# 94992   5JFECZ0kdOJSQ7hZedoSPI  Tumhare Hain Tumse Dua Mangte           2
# 515280  2tR9TEvkuxxw0JLcumBSeq  Tumhare Hain Tumse Dua Mangte           2
# 536923  2cAliAJNPVdKEGxv6kiOEg         Hum Ko Tumhare Ishq Ne           6
# 581246  4dSo5fqkP5W27tzZvYNNNK                  Av ingens frö          23
# 217087  1h4wbNA48HRxyoziXujCyR         La Rosa De Los Vientos          48
# 580525  6jbqglQeYgas5XnW7o8qLV               Who Put The Bomp          26
# 125814  3Rf3a5dmLXQIjvDnS7sSbp           That Old Black Magic          15
# 291388  2F7PIv53uzQvAsVgshrO3k                          100 %          22
# 319362  6M7nGN8qbSpN9cNY48nH4j                    Óskasteinar          11
# 160827  6XpUeeBN24JBMTtl3v4NHA                  Kaksi kitaraa           4
# 137926  26Oi9kkRouZIA5o8vSnzjY                  Kaksi kitaraa          14
# 574670  3wQXXfPs1DFFF7JMOBuGDm                  The Last Time          35
# ...
